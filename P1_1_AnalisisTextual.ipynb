# %% [markdown]
# <a href="https://colab.research.google.com/github/alvumu/TGINE/blob/main/P1_1_AnalisisTextual.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Sesión 1. Análisis textual en Python
#
# En esta sesión se pretende trabajar con algunos de los conceptos básicos de Python para el procesamiento de texto.

# %% [markdown]
# ##Apartado 1.0
#
# Descargamos primero el dataset "datasetEspañol.csv" con el que vamos a trabajar.

# %%
# !wget http://dis.um.es/~valencia/recursosTGINE/datasetEspañol.csv
# Out:
# --2023-10-11 07:52:48--  http://dis.um.es/~valencia/recursosTGINE/datasetEspa%C3%B1ol.csv
# Resolving dis.um.es (dis.um.es)... 155.54.239.5
# Connecting to dis.um.es (dis.um.es)|155.54.239.5|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1953117 (1.9M) [text/csv]
# Saving to: ‘datasetEspañol.csv’
#
# datasetEspañol.csv  100%[===================>]   1.86M  1.47MB/s    in 1.3s
#
# 2023-10-11 07:52:50 (1.47 MB/s) - ‘datasetEspañol.csv’ saved [1953117/1953117]

# %% [markdown]
# ## Apartado 1.1
# Para ello cargaremos primero el dataset en CSV proporcionado "datasetEspañol.csv" usando la librería **pandas**
#
# Mostraremos también las primeras líneas del CSV cargado

# %%
import pandas as pd
import csv

data = pd.read_csv('datasetEspañol.csv', encoding = "UTF-8")

# %% [markdown]
# ## Apartado 1.2
#
# Seleccionamos únicamente las 200 primeras filas y las columnas 'twitter_id', 'twitter_created_at', 'tweet', 'user' y 'label' y guardamos de nuevo el CSV en el fichero "datasetEspañolReducido.csv".
#
# A partir de ahora trabajaremos con este dataset reducido.

# %%
data2 = data[0:200][[ 'tweet', 'user' , 'label' ]]
data2.tail()
data2.to_csv('datasetEspañolreducido.csv', encoding ="UTF-8", index = False, quoting=csv.QUOTE_ALL)

# %% [markdown]
# ## Apartado 1.3
#
# Ahora trabajaremos detectando de manera sencilla algunas expresiones regulares usando la librería **re**.
#
# Para ello seleccionaremos los **hashtags** y **menciones** de los tuits.
#
# Una expresión regular para detectar los hashtags podría ser la siguiente:
# \#[A-Za-záéíóúÁÉÍÓÚÜüÑñ0-9\_\-]+
#
# Además, crearemos una nueva columna 'tweet_clean' que no contenga los hashtags ni menciones.
#
# - Usaremos la función "apply" y "lambda" de Pandas.
# - Para detectar si la expresión regular existe en un determinado String usaremos la función re.sub()

# %%
import re
#Definimos las expresiones regulares para hashtag y menciones
hashtagregex ="#[A-Za-záéíóúÁÉÍÓÚÜüÑñ0-9_-]+"
mentionsregex ="@[A-Za-záéíóúÁÉÍÓÚÜüÑñ0-9_-]+"
data2['tweet_clean'] = data2['tweet'].apply(lambda x: re.sub(hashtagregex,"",x))
data2['tweet_clean'] = data2['tweet_clean'].apply(lambda x: re.sub(mentionsregex,"",x))
data2.tail()
# Out:
#                                                  tweet             user  \
# 195  Bueno...pues ya está!... Ya tengo ordenados lo...    Tuitero_David
# 196  Han cerrado el corte ingles y ya no tengo que ...   AinhoaDelPilar
# 197  Juventud de España!!! Quedaos en casa. #YoMeQu...         XulesRun
# 198  Saludos desde @CADENA100 aquí también estamos ...  NavarroAlmudena
# 199  HOMENAJE A TODOS LOS SANITARIOS ??A LAS DIEZ H...   Anakin73630326
#
#         label                                        tweet_clean
# 195  positive  Bueno...pues ya está!... Ya tengo ordenados lo...
# 196  positive  Han cerrado el corte ingles y ya no tengo que ...
# 197  positive      Juventud de España!!! Quedaos en casa. . . .
# 198  positive  Saludos desde  aquí también estamos cumpliendo...
# 199  positive  HOMENAJE A TODOS LOS SANITARIOS ??A LAS DIEZ H...

# %% [markdown]
# ## Apartado 1.4
#
# Una vez detectadas las expresiones regulares, procederemos a crear dos nuevas columnas con los **hashtags** y **menciones** respectivamente.
#
# - Podemos usar la función re.findall()

# %%
hashtagregex ="#[A-Za-záéíóúÁÉÍÓÚÜüÑñ0-9_-]+"
mentionsregex ="@[A-Za-záéíóúÁÉÍÓÚÜüÑñ0-9_-]+"

data2['hashtags'] = data2['tweet'].apply(lambda x: re.findall(hashtagregex,x))
data2['menciones'] = data2['tweet'].apply(lambda x: re.findall(mentionsregex,x))
data2.head()
# Out:
#                                                tweet             user  \
# 0  Hoy merendola deliciosa! Latte Macchiato Caram...         Lorenhia
# 1  Muchos ánimos a todos los compañeros, profesio...  VacunaJesusRuiz
# 2  Hay TANTAS cosas que se pueden hacer en casa: ...    jbautyoficial
# 3  #GabineteDeCrisisUtil #16 Escucha música! la q...         ton1pons
# 4  Increible el festival de musica gratuito que h...        Alexiat84
#
#       label                                        tweet_clean  \
# 0  positive  Hoy merendola deliciosa! Latte Macchiato Caram...
# 1  positive  Muchos ánimos a todos los compañeros, profesio...
# 2  positive  Hay TANTAS cosas que se pueden hacer en casa: ...
# 3  positive    Escucha música! la que te gusta, pero tambié...
# 4  positive  Increible el festival de musica gratuito que h...
#
#                                             hashtags      menciones
# 0  [#yomequedoencasa, #todovaasalirbien, #undiame...             []
# 1      [#CoronavirusESP, #YoMeQuedoEnCasa, #vacunas]             []
# 2               [#YoMeQuedoEnCasa, #quedateEnTuCasa]             []
# 3  [#GabineteDeCrisisUtil, #16, #YoMeQuedoEnCasa,...             []
# 4                                 [#YoMeQuedoEnCasa]  [@NilMoliner]

# %% [markdown]
# ## Apartado 1.5
#
# Sobre esa nueva columna 'tweet_clean' quitaremos los símbolos de puntuación haciendo uso de la librería **string**
#
# Podemos usar la siguiente función
#
# ```
# #defining the function to remove punctuation
# import string
#
# spanish_punctuation = string.punctuation+'¿'+'¡'
# def remove_punctuation(text):
#     punctuationfree="".join([i for i in text if i not in spanish_punctuation])
#     return punctuationfree
#
# ```

# %%
# defining the function to remove punctuation
import string

spanish_punctuation = string.punctuation+'¿'+'¡'
def remove_punctuation(text):
    punctuationfree="".join([i for i in text if i not in spanish_punctuation])

    return punctuationfree

data2['tweet_clean'] = data2['tweet_clean'].apply(lambda x: remove_punctuation(x.strip()))
data2.head()
# Out:
#                                                tweet             user  \
# 0  Hoy merendola deliciosa! Latte Macchiato Caram...         Lorenhia
# 1  Muchos ánimos a todos los compañeros, profesio...  VacunaJesusRuiz
# 2  Hay TANTAS cosas que se pueden hacer en casa: ...    jbautyoficial
# 3  #GabineteDeCrisisUtil #16 Escucha música! la q...         ton1pons
# 4  Increible el festival de musica gratuito que h...        Alexiat84
#
#       label                                        tweet_clean
# 0  positive  Hoy merendola deliciosa Latte Macchiato Carame...
# 1  positive  Muchos ánimos a todos los compañeros profesion...
# 2  positive  Hay TANTAS cosas que se pueden hacer en casa v...
# 3  positive  Escucha música la que te gusta pero también la...
# 4  positive  Increible el festival de musica gratuito que h...

# %% [markdown]
# ## Apartado 1.6
#
# Cambiamos el texto de la columna 'tweet_clean' y lo podemos todo en *lowercase*.
#
# Para eso utilizamos la función lower() del objeto string

# %%
data2['tweet_clean'] = data2['tweet_clean'].apply(lambda x : x.lower())
data2.head()
# Out:
#                                                tweet             user  \
# 0  Hoy merendola deliciosa! Latte Macchiato Caram...         Lorenhia
# 1  Muchos ánimos a todos los compañeros, profesio...  VacunaJesusRuiz
# 2  Hay TANTAS cosas que se pueden hacer en casa: ...    jbautyoficial
# 3  #GabineteDeCrisisUtil #16 Escucha música! la q...         ton1pons
# 4  Increible el festival de musica gratuito que h...        Alexiat84
#
#       label                                        tweet_clean  \
# 0  positive  hoy merendola deliciosa latte macchiato carame...
# 1  positive  muchos ánimos a todos los compañeros profesion...
# 2  positive  hay tantas cosas que se pueden hacer en casa v...
# 3  positive  escucha música la que te gusta pero también la...
# 4  positive  increible el festival de musica gratuito que h...
#
#                                             hashtags      menciones
# 0  [#yomequedoencasa, #todovaasalirbien, #undiame...             []
# 1      [#CoronavirusESP, #YoMeQuedoEnCasa, #vacunas]             []
# 2               [#YoMeQuedoEnCasa, #quedateEnTuCasa]             []
# 3  [#GabineteDeCrisisUtil, #16, #YoMeQuedoEnCasa,...             []
# 4                                 [#YoMeQuedoEnCasa]  [@NilMoliner]

# %% [markdown]
# ## Apartado 1.7
#
# Aplicamos un tokenizer sencillo y guardamos todos los tokens de los tuits limpios en otra columna 'tweet_clean_tokens' usando la siguiente función sencilla de Tokenizer.
#
# ```
# #defining function for tokenization
# import re
# def tokenization(text):
#     tokens = re.split('\W+',text)
#     return tokens
# ```

# %%
# defining function for tokenization
import re
def tokenization(text):
    tokens = re.split('\W+',text)
    return tokens

data2['tweet_clean_tokens'] = data2['tweet_clean'].apply(lambda x : tokenization(x))
data2.head()
# Out:
#                                                tweet             user  \
# 0  Hoy merendola deliciosa! Latte Macchiato Caram...         Lorenhia
# 1  Muchos ánimos a todos los compañeros, profesio...  VacunaJesusRuiz
# 2  Hay TANTAS cosas que se pueden hacer en casa: ...    jbautyoficial
# 3  #GabineteDeCrisisUtil #16 Escucha música! la q...         ton1pons
# 4  Increible el festival de musica gratuito que h...        Alexiat84
#
#       label                                        tweet_clean  \
# 0  positive  Hoy merendola deliciosa Latte Macchiato Carame...
# 1  positive  Muchos ánimos a todos los compañeros profesion...
# 2  positive  Hay TANTAS cosas que se pueden hacer en casa v...
# 3  positive  Escucha música la que te gusta pero también la...
# 4  positive  Increible el festival de musica gratuito que h...
#
#                                             hashtags      menciones  \
# 0  [#yomequedoencasa, #todovaasalirbien, #undiame...             []
# 1      [#CoronavirusESP, #YoMeQuedoEnCasa, #vacunas]             []
# 2               [#YoMeQuedoEnCasa, #quedateEnTuCasa]             []
# 3  [#GabineteDeCrisisUtil, #16, #YoMeQuedoEnCasa,...             []
# 4                                 [#YoMeQuedoEnCasa]  [@NilMoliner]
#
#                                   tweet_clean_tokens
# 0  [Hoy, merendola, deliciosa, Latte, Macchiato, ...
# 1  [Muchos, ánimos, a, todos, los, compañeros, pr...
# 2  [Hay, TANTAS, cosas, que, se, pueden, hacer, e...
# 3  [Escucha, música, la, que, te, gusta, pero, ta...
# 4  [Increible, el, festival, de, musica, gratuito...

# %% [markdown]
# ## Apartado 1.8
#
# **NLTK** es una librería con distintas herramientas para el PLN. La vamos a utilizar para descargar las stopwords en español y para usar su stemmer.
#
# El siguiente paso sería eliminar las stopwords de los tokens usando la librería **NLTK**. Ver función siguiente.
#
#
#
# ```
# import nltk
# #Stop words present in the library
# nltk.download('stopwords')
# stopwords = nltk.corpus.stopwords.words('spanish')
#
#
# #defining the function to remove stopwords from tokenized text
# def remove_stopwords(text):
#     output= [i for i in text if i not in stopwords]
#     return output
#
# ```

# %%
import nltk
# Stop words present in the library
nltk.download('stopwords')
stopwords = nltk.corpus.stopwords.words('spanish')


# defining the function to remove stopwords from tokenized text
def remove_stopwords(text):
    output= [i for i in text if i not in stopwords]
    return output

data2['tweet_clean_tokens'] = data2['tweet_clean_tokens'].apply(lambda x : remove_stopwords(x))
data2.head()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#                                                tweet             user  \
# 0  Hoy merendola deliciosa! Latte Macchiato Caram...         Lorenhia
# 1  Muchos ánimos a todos los compañeros, profesio...  VacunaJesusRuiz
# 2  Hay TANTAS cosas que se pueden hacer en casa: ...    jbautyoficial
# 3  #GabineteDeCrisisUtil #16 Escucha música! la q...         ton1pons
# 4  Increible el festival de musica gratuito que h...        Alexiat84
#
#       label                                        tweet_clean  \
# 0  positive  Hoy merendola deliciosa Latte Macchiato Carame...
# 1  positive  Muchos ánimos a todos los compañeros profesion...
# 2  positive  Hay TANTAS cosas que se pueden hacer en casa v...
# 3  positive  Escucha música la que te gusta pero también la...
# 4  positive  Increible el festival de musica gratuito que h...
#
#                                             hashtags      menciones  \
# 0  [#yomequedoencasa, #todovaasalirbien, #undiame...             []
# 1      [#CoronavirusESP, #YoMeQuedoEnCasa, #vacunas]             []
# 2               [#YoMeQuedoEnCasa, #quedateEnTuCasa]             []
# 3  [#GabineteDeCrisisUtil, #16, #YoMeQuedoEnCasa,...             []
# 4                                 [#YoMeQuedoEnCasa]  [@NilMoliner]
#
#                                   tweet_clean_tokens
# 0  [Hoy, merendola, deliciosa, Latte, Macchiato, ...
# 1  [Muchos, ánimos, compañeros, profesionales, sa...
# 2  [Hay, TANTAS, cosas, pueden, hacer, casa, ver,...
# 3  [Escucha, música, gusta, hace, años, escuchaba...
# 4  [Increible, festival, musica, gratuito, organi...

# %% [markdown]
# ## Apartado 1.9
#
# Por último usando el SnowballStemmer de NLTK obtenemos los stems de cada una de los tokens sin las stopwords y lo guardamos en otra columna 'tweet_clean_stemmed_tokens'
#
#
#
# ```
# from nltk.stem import SnowballStemmer
# stemmer = SnowballStemmer('spanish')
#
# #defining a function for stemming
# def stemming(text):
#   stem_text = [stemmer.stem(word) for word in text]
#   return stem_text
#   ```

# %%
from nltk.stem import SnowballStemmer
stemmer = SnowballStemmer('spanish')

# defining a function for stemming
def stemming(text):
  stem_text = [stemmer.stem(word) for word in text]
  return stem_text

data2['tweet_clean_stemmed_tokens'] = data2['tweet_clean_tokens'].apply(lambda x : stemming(x))
data2.head()
# Out:
#                                                tweet             user  \
# 0  Hoy merendola deliciosa! Latte Macchiato Caram...         Lorenhia
# 1  Muchos ánimos a todos los compañeros, profesio...  VacunaJesusRuiz
# 2  Hay TANTAS cosas que se pueden hacer en casa: ...    jbautyoficial
# 3  #GabineteDeCrisisUtil #16 Escucha música! la q...         ton1pons
# 4  Increible el festival de musica gratuito que h...        Alexiat84
#
#       label                                        tweet_clean  \
# 0  positive  Hoy merendola deliciosa Latte Macchiato Carame...
# 1  positive  Muchos ánimos a todos los compañeros profesion...
# 2  positive  Hay TANTAS cosas que se pueden hacer en casa v...
# 3  positive  Escucha música la que te gusta pero también la...
# 4  positive  Increible el festival de musica gratuito que h...
#
#                                             hashtags      menciones  \
# 0  [#yomequedoencasa, #todovaasalirbien, #undiame...             []
# 1      [#CoronavirusESP, #YoMeQuedoEnCasa, #vacunas]             []
# 2               [#YoMeQuedoEnCasa, #quedateEnTuCasa]             []
# 3  [#GabineteDeCrisisUtil, #16, #YoMeQuedoEnCasa,...             []
# 4                                 [#YoMeQuedoEnCasa]  [@NilMoliner]
#
#                                   tweet_clean_tokens  \
# 0  [Hoy, merendola, deliciosa, Latte, Macchiato, ...
# 1  [Muchos, ánimos, compañeros, profesionales, sa...
# 2  [Hay, TANTAS, cosas, pueden, hacer, casa, ver,...
# 3  [Escucha, música, gusta, hace, años, escuchaba...
# 4  [Increible, festival, musica, gratuito, organi...
#
#                           tweet_clean_stemmed_tokens
# 0  [hoy, merendol, delici, latt, macchiat, carame...
# 1  [much, anim, compañer, profesional, sanitari, ...
# 2  [hay, tant, cos, pued, hac, cas, ver, cin, ser...
# 3  [escuch, music, gust, hac, años, escuch, telet...
# 4  [increibl, festival, music, gratuit, organiz, ...

# %% [markdown]
# ##Apartado 1.10  Simple corrección ortográfica (Resuelto)
# Muchos textos tienen errores léxicos y hay distintas librerías para la corrección ortográfica a partir de diccionarios. Una de ellas es la librería **pyspellchecker**
#
# Hay otras opciones como hunspell y pyenchant que hacen una corrección léxica basada en diccionarios

# %%
# instalamos la libería
# !pip3 install pyspellchecker

#importamos la librería
import spellchecker

texto_erróneo = "La asginatura del master haze trabajar y aprehnder procesamiengo de teexto"

# Crea un objeto SpellChecker para el idioma especificado
spell = spellchecker.SpellChecker(language='es')

# Divide el texto en palabras
palabras = texto_erróneo.split()

# Inicializa una lista para las palabras corregidas
palabras_corregidas = []

# Verifica cada palabra en el texto
for palabra in palabras:
# Si la palabra está mal escrita, sugiere correcciones
   correccion = spell.correction(palabra)
   palabras_corregidas.append(correccion)

# Unimos las palabras corregidas para formar el texto corregido
texto_corregido = ' '.join(palabras_corregidas)
print(texto_corregido)
# Out:
# Collecting pyspellchecker
#   Downloading pyspellchecker-0.7.2-py3-none-any.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 28.4 MB/s eta 0:00:00
# Installing collected packages: pyspellchecker
# Successfully installed pyspellchecker-0.7.2
# La asignatura del master hace trabajar y aprender procesamiento de texto

# %% [markdown]
# ## Ejercicio a resolver y entregar
# Una vez visto el framework stanza en el siguiente Notebook P1.2, crear una columna 'tweet_entities' con las entidades del texto.
#
# Una mejora de este ejercicio es crear una columna para cada tipo de entidad detectada. Esto es necesario para tener la máxima nota en el ejercicio
#
# Debido a que puede tardar bastante tiempo, podéis hacerlo con un subconjunto del dataset de unas 20 líneas.

# %%
# !pip3 install stanza
import stanza
stanza.download('es')
pipelineStanza = stanza.Pipeline(lang='es', processors='tokenize ,mwt, pos, lemma, depparse,ner')
# Out:
# Requirement already satisfied: stanza in /usr/local/lib/python3.10/dist-packages (1.6.1)
# Requirement already satisfied: emoji in /usr/local/lib/python3.10/dist-packages (from stanza) (2.8.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from stanza) (1.23.5)
# Requirement already satisfied: protobuf>=3.15.0 in /usr/local/lib/python3.10/dist-packages (from stanza) (3.20.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from stanza) (2.31.0)
# Requirement already satisfied: torch>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from stanza) (2.0.1+cu118)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from stanza) (4.66.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (3.12.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.3.0->stanza) (3.27.6)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.3.0->stanza) (17.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->stanza) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->stanza) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->stanza) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->stanza) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.3.0->stanza) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.3.0->stanza) (1.3.0)
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# INFO:stanza:Downloading default packages for language: es (Spanish) ...
# INFO:stanza:File exists: /root/stanza_resources/es/default.zip
# INFO:stanza:Finished downloading models and saved to /root/stanza_resources.
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# INFO:stanza:Loading these models for language: es (Spanish):
# ===============================
# | Processor | Package         |
# -------------------------------
# | tokenize  | ancora          |
# | mwt       | ancora          |
# | pos       | ancora_charlm   |
# | lemma     | ancora_nocharlm |
# | depparse  | ancora_charlm   |
# | ner       | conll02         |
# ===============================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: mwt
# INFO:stanza:Loading: pos
# INFO:stanza:Loading: lemma
# INFO:stanza:Loading: depparse
# INFO:stanza:Loading: ner
# INFO:stanza:Done loading processors!

# %%
import pandas as pd
from collections import defaultdict


# Creamos un DataFrame vacío
df = pd.DataFrame(columns=["tweet_entities", "PER", "ORG", "LOC", "MISC"])

for row in data2["tweet_clean"]:
    stanzaDoc = pipelineStanza(row)

    # Creamos un diccionario para almacenar los tipos de cada entidad
    entity_dict = defaultdict(list)

     # Recogemos todas las entidades y las almacenamos en el diccionario
    for sent in stanzaDoc.sentences:
        for ent in sent.ents:
            entity_dict[ent.type].append(ent.text)

    #Obtenemos la lista de los nombres de las entidades
    entities = [ent.text for sent in stanzaDoc.sentences for ent in sent.ents]

    # Creamos un dataframe para almacenar todas las entidades de los tweets
    new_data = {"tweet_entities": [entities]}

    # Añadimos los tipos de entidades a la coleccion obteniendolos del diccionario
    for ent_type in ["PER", "ORG", "LOC", "MISC"]:
        new_data[ent_type] = [entity_dict[ent_type]]

    #Convertimos la coleccion en un dataframe
    new_df = pd.DataFrame(new_data)

    # Concatenamos el nuevo DataFrame al DataFrame principal
    df = pd.concat([df, new_df], ignore_index=True)

# %%
#Reducimos el dataset original para comparar los datos y los concatenamos
pd.concat([data2, df],axis=1)
# Out:
#                                                  tweet             user  \
# 0    Hoy merendola deliciosa! Latte Macchiato Caram...         Lorenhia
# 1    Muchos ánimos a todos los compañeros, profesio...  VacunaJesusRuiz
# 2    Hay TANTAS cosas que se pueden hacer en casa: ...    jbautyoficial
# 3    #GabineteDeCrisisUtil #16 Escucha música! la q...         ton1pons
# 4    Increible el festival de musica gratuito que h...        Alexiat84
# ..                                                 ...              ...
# 195  Bueno...pues ya está!... Ya tengo ordenados lo...    Tuitero_David
# 196  Han cerrado el corte ingles y ya no tengo que ...   AinhoaDelPilar
# 197  Juventud de España!!! Quedaos en casa. #YoMeQu...         XulesRun
# 198  Saludos desde @CADENA100 aquí también estamos ...  NavarroAlmudena
# 199  HOMENAJE A TODOS LOS SANITARIOS ??A LAS DIEZ H...   Anakin73630326
#
#         label                                        tweet_clean  \
# 0    positive  Hoy merendola deliciosa Latte Macchiato Carame...
# 1    positive  Muchos ánimos a todos los compañeros profesion...
# 2    positive  Hay TANTAS cosas que se pueden hacer en casa v...
# 3    positive  Escucha música la que te gusta pero también la...
# 4    positive  Increible el festival de musica gratuito que h...
# ..        ...                                                ...
# 195  positive  Buenopues ya está Ya tengo ordenados los condo...
# 196  positive  Han cerrado el corte ingles y ya no tengo que ...
# 197  positive              Juventud de España Quedaos en casa
# 198  positive  Saludos desde  aquí también estamos cumpliendo...
# 199  positive  HOMENAJE A TODOS LOS SANITARIOS A LAS DIEZ HOR...
#
#                                         tweet_entities  \
# 0    [Latte Macchiato Caramelo, Leche Condensada, G...
# 1                                           [SARSCOV2]
# 2                                                   []
# 3                                                   []
# 4                                       [Soldadito de]
# ..                                                 ...
# 195                                        [Buenopues]
# 196                                                 []
# 197                       [Juventud de España Quedaos]
# 198                                                 []
# 199                                                 []
#
#                                    PER                           ORG LOC  \
# 0    [Latte Macchiato Caramelo, Gofre]                            []  []
# 1                                   []                            []  []
# 2                                   []                            []  []
# 3                                   []                            []  []
# 4                                   []                [Soldadito de]  []
# ..                                 ...                           ...  ..
# 195                        [Buenopues]                            []  []
# 196                                 []                            []  []
# 197                                 []  [Juventud de España Quedaos]  []
# 198                                 []                            []  []
# 199                                 []                            []  []
#
#                    MISC
# 0    [Leche Condensada]
# 1            [SARSCOV2]
# 2                    []
# 3                    []
# 4                    []
# ..                  ...
# 195                  []
# 196                  []
# 197                  []
# 198                  []
# 199                  []
#
# [200 rows x 9 columns]
