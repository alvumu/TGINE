# %% [markdown]
# # Sesión 1 - Parte 2. Stanza
#
# Stanza es una API que proporciona sevicios de PLN organizados en tuberías o Pipelines.
#
# El objetivo de la práctica es crear un pipeline de Stanza en español e ir procesando un texto de ejemplo.
#
# Lo primero que haremos será instalar Stanza y descargar el modelo en español. Tened en cuenta que se pueden descargar modelos en distintos idiomas

# %%
# !pip3 install stanza
import stanza
stanza.download('es')
# Out:
# Collecting stanza
#   Downloading stanza-1.6.0-py3-none-any.whl (880 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 880.1/880.1 kB 12.1 MB/s eta 0:00:00
# Collecting emoji (from stanza)
#   Downloading emoji-2.8.0-py2.py3-none-any.whl (358 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 358.9/358.9 kB 32.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from stanza) (1.23.5)
# Requirement already satisfied: protobuf>=3.15.0 in /usr/local/lib/python3.10/dist-packages (from stanza) (3.20.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from stanza) (2.31.0)
# Requirement already satisfied: torch>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from stanza) (2.0.1+cu118)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from stanza) (4.66.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (3.12.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.3.0->stanza) (3.27.6)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.3.0->stanza) (17.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->stanza) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->stanza) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->stanza) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->stanza) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.3.0->stanza) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.3.0->stanza) (1.3.0)
# Installing collected packages: emoji, stanza
# Successfully installed emoji-2.8.0 stanza-1.6.0
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# INFO:stanza:Downloading default packages for language: es (Spanish) ...
# Downloading https://huggingface.co/stanfordnlp/stanza-es/resolve/v1.6.0/models/default.zip:   0%|          | 0…
# INFO:stanza:Finished downloading models and saved to /root/stanza_resources.

# %% [markdown]
# ## Apartado 1.1 - Resuelto
#
# Definimos un texto en español de varias líneas y probamos el Tokenizer en español.
#
# Para ello se definirá un Pipeline de Stanza únicamente con la fase 'tokenize'.

# %%
#Probamos el tokenizer en español
text = """Hugo, Valencia tiene playa.

Juan Manuel Garcia Martinez juega al fútbol con Emma y Cristina con una pelota roja en Central Park.

El padre de Marina tiene 56 años.

La Tierra gira alrededor del Sol.

Júpiter es el planeta más grande del Sistema Solar"""

pipelineStanza = stanza.Pipeline(lang='es', processors='tokenize')
stanzaDoc = pipelineStanza(text)

print("Número de frases:" + str(len(stanzaDoc.sentences)))
for sentence in stanzaDoc.sentences:
  print(sentence)
# Out:
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# WARNING:stanza:Language es package default expects mwt, which has been added
# INFO:stanza:Loading these models for language: es (Spanish):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | ancora  |
# | mwt       | ancora  |
# =======================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: mwt
# INFO:stanza:Done loading processors!
# Número de frases:5
# [
#   {
#     "id": 1,
#     "text": "Hugo",
#     "start_char": 0,
#     "end_char": 4
#   },
#   {
#     "id": 2,
#     "text": ",",
#     "start_char": 4,
#     "end_char": 5
#   },
#   {
#     "id": 3,
#     "text": "Valencia",
#     "start_char": 6,
#     "end_char": 14
#   },
#   {
#     "id": 4,
#     "text": "tiene",
#     "start_char": 15,
#     "end_char": 20
#   },
#   {
#     "id": 5,
#     "text": "playa",
#     "start_char": 21,
#     "end_char": 26
#   },
#   {
#     "id": 6,
#     "text": ".",
#     "start_char": 26,
#     "end_char": 27
#   }
# ]
# [
#   {
#     "id": 1,
#     "text": "Juan",
#     "start_char": 29,
#     "end_char": 33
#   },
#   {
#     "id": 2,
#     "text": "Manuel",
#     "start_char": 34,
#     "end_char": 40
#   },
#   {
#     "id": 3,
#     "text": "Garcia",
#     "start_char": 41,
#     "end_char": 47
#   },
#   {
#     "id": 4,
#     "text": "Martinez",
#     "start_char": 48,
#     "end_char": 56
#   },
#   {
#     "id": 5,
#     "text": "juega",
#     "start_char": 57,
#     "end_char": 62
#   },
#   {
#     "id": [
#       6,
#       7
#     ],
#     "text": "al",
#     "start_char": 63,
#     "end_char": 65
#   },
#   {
#     "id": 6,
#     "text": "a"
#   },
#   {
#     "id": 7,
#     "text": "el"
#   },
#   {
#     "id": 8,
#     "text": "fútbol",
#     "start_char": 66,
#     "end_char": 72
#   },
#   {
#     "id": 9,
#     "text": "con",
#     "start_char": 73,
#     "end_char": 76
#   },
#   {
#     "id": 10,
#     "text": "Emma",
#     "start_char": 77,
#     "end_char": 81
#   },
#   {
#     "id": 11,
#     "text": "y",
#     "start_char": 82,
#     "end_char": 83
#   },
#   {
#     "id": 12,
#     "text": "Cristina",
#     "start_char": 84,
#     "end_char": 92
#   },
#   {
#     "id": 13,
#     "text": "con",
#     "start_char": 93,
#     "end_char": 96
#   },
#   {
#     "id": 14,
#     "text": "una",
#     "start_char": 97,
#     "end_char": 100
#   },
#   {
#     "id": 15,
#     "text": "pelota",
#     "start_char": 101,
#     "end_char": 107
#   },
#   {
#     "id": 16,
#     "text": "roja",
#     "start_char": 108,
#     "end_char": 112
#   },
#   {
#     "id": 17,
#     "text": "en",
#     "start_char": 113,
#     "end_char": 115
#   },
#   {
#     "id": 18,
#     "text": "Central",
#     "start_char": 116,
#     "end_char": 123
#   },
#   {
#     "id": 19,
#     "text": "Park",
#     "start_char": 124,
#     "end_char": 128
#   },
#   {
#     "id": 20,
#     "text": ".",
#     "start_char": 128,
#     "end_char": 129
#   }
# ]
# [
#   {
#     "id": 1,
#     "text": "El",
#     "start_char": 131,
#     "end_char": 133
#   },
#   {
#     "id": 2,
#     "text": "padre",
#     "start_char": 134,
#     "end_char": 139
#   },
#   {
#     "id": 3,
#     "text": "de",
#     "start_char": 140,
#     "end_char": 142
#   },
#   {
#     "id": 4,
#     "text": "Marina",
#     "start_char": 143,
#     "end_char": 149
#   },
#   {
#     "id": 5,
#     "text": "tiene",
#     "start_char": 150,
#     "end_char": 155
#   },
#   {
#     "id": 6,
#     "text": "56",
#     "start_char": 156,
#     "end_char": 158
#   },
#   {
#     "id": 7,
#     "text": "años",
#     "start_char": 159,
#     "end_char": 163
#   },
#   {
#     "id": 8,
#     "text": ".",
#     "start_char": 163,
#     "end_char": 164
#   }
# ]
# [
#   {
#     "id": 1,
#     "text": "La",
#     "start_char": 166,
#     "end_char": 168
#   },
#   {
#     "id": 2,
#     "text": "Tierra",
#     "start_char": 169,
#     "end_char": 175
#   },
#   {
#     "id": 3,
#     "text": "gira",
#     "start_char": 176,
#     "end_char": 180
#   },
#   {
#     "id": 4,
#     "text": "alrededor",
#     "start_char": 181,
#     "end_char": 190
#   },
#   {
#     "id": [
#       5,
#       6
#     ],
#     "text": "del",
#     "start_char": 191,
#     "end_char": 194
#   },
#   {
#     "id": 5,
#     "text": "de"
#   },
#   {
#     "id": 6,
#     "text": "el"
#   },
#   {
#     "id": 7,
#     "text": "Sol",
#     "start_char": 195,
#     "end_char": 198
#   },
#   {
#     "id": 8,
#     "text": ".",
#     "start_char": 198,
#     "end_char": 199
#   }
# ]
# [
#   {
#     "id": 1,
#     "text": "Júpiter",
#     "start_char": 201,
#     "end_char": 208
#   },
#   {
#     "id": 2,
#     "text": "es",
#     "start_char": 209,
#     "end_char": 211
#   },
#   {
#     "id": 3,
#     "text": "el",
#     "start_char": 212,
#     "end_char": 214
#   },
#   {
#     "id": 4,
#     "text": "planeta",
#     "start_char": 215,
#     "end_char": 222
#   },
#   {
#     "id": 5,
#     "text": "más",
#     "start_char": 223,
#     "end_char": 226
#   },
#   {
#     "id": 6,
#     "text": "grande",
#     "start_char": 227,
#     "end_char": 233
#   },
#   {
#     "id": [
#       7,
#       8
#     ],
#     "text": "del",
#     "start_char": 234,
#     "end_char": 237
#   },
#   {
#     "id": 7,
#     "text": "de"
#   },
#   {
#     "id": 8,
#     "text": "el"
#   },
#   {
#     "id": 9,
#     "text": "Sistema",
#     "start_char": 238,
#     "end_char": 245
#   },
#   {
#     "id": 10,
#     "text": "Solar",
#     "start_char": 246,
#     "end_char": 251
#   }
# ]

# %%
#Obtenemos una matriz con todos los tokens por frase
for sentence in stanzaDoc.sentences:
  for token in sentence.tokens:
    print(token.text)
# Out:
# Hugo
# come
# manzanas
# en
# la
# cocina
# de
# Telefónica
# .
# Sofía
# juega
# al
# fútbol
# con
# Emma
# y
# Cristina
# con
# una
# pelota
# roja
# en
# Central
# Park
# .
# El
# padre
# de
# Marina
# tiene
# 56
# años
# .
# La
# Tierra
# gira
# alrededor
# del
# Sol
# .
# Júpiter
# es
# el
# planeta
# más
# grande
# del
# Sistema
# Solar

# %% [markdown]
# ## Apartado 1.2
#
# Ahora vamos a probar el pipeline metiendo un analizador morfológico esto es 'tokenize, mwt, pos'
#
# Mostramos entonces cada palabra (*word*) de cada frase (*sentence*) junto con su categoría gramatical (*upos*).

# %%
pipelineStanza = stanza.Pipeline(lang='es', processors='tokenize ,mwt, pos')
stanzaDoc = pipelineStanza(text)

print("Número de frases: " + str(len(stanzaDoc.sentences)))
for sentence in stanzaDoc.sentences:
  frase = ""
  for word in sentence.words:
    frase = frase+word.text+"_"+word.upos+" "
  print("Frase : "+frase)
# Out:
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# INFO:stanza:Loading these models for language: es (Spanish):
# =============================
# | Processor | Package       |
# -----------------------------
# | tokenize  | ancora        |
# | mwt       | ancora        |
# | pos       | ancora_charlm |
# =============================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: mwt
# INFO:stanza:Loading: pos
# INFO:stanza:Done loading processors!
# Número de frases: 5
# Frase : Hugo_PROPN come_VERB manzanas_NOUN en_ADP la_DET cocina_NOUN de_ADP Telefónica_PROPN ._PUNCT
# Frase : Sofía_PROPN juega_VERB a_ADP el_DET fútbol_NOUN con_ADP Emma_PROPN y_CCONJ Cristina_PROPN con_ADP una_DET pelota_NOUN roja_ADJ en_ADP Central_PROPN Park_PROPN ._PUNCT
# Frase : El_DET padre_NOUN de_ADP Marina_PROPN tiene_VERB 56_NUM años_NOUN ._PUNCT
# Frase : La_DET Tierra_PROPN gira_VERB alrededor_ADV de_ADP el_DET Sol_PROPN ._PUNCT
# Frase : Júpiter_PROPN es_AUX el_DET planeta_NOUN más_ADV grande_ADJ de_ADP el_DET Sistema_PROPN Solar_PROPN

# %% [markdown]
# ## Apartado 1.3
#
# A continuación incluimos en el Pipeline la lemmatización (*lemma*) y la imprimimos al lado de la palabra entre paréntesis

# %%
pipelineStanza = stanza.Pipeline(lang='es', processors='tokenize ,mwt, pos, lemma')
stanzaDoc = pipelineStanza(text)

print("Número de frases: " + str(len(stanzaDoc.sentences)))
for sentence in stanzaDoc.sentences:
  frase = ""
  for word in sentence.words:
    frase = frase+word.text+"("+word.lemma+")"+"_"+word.upos+" "
  print("Frase : "+frase)
# Out:
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# INFO:stanza:Loading these models for language: es (Spanish):
# ===============================
# | Processor | Package         |
# -------------------------------
# | tokenize  | ancora          |
# | mwt       | ancora          |
# | pos       | ancora_charlm   |
# | lemma     | ancora_nocharlm |
# ===============================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: mwt
# INFO:stanza:Loading: pos
# INFO:stanza:Loading: lemma
# INFO:stanza:Done loading processors!
# Número de frases: 5
# Frase : Hugo(Hugo)_PROPN come(come)_VERB manzanas(manzana)_NOUN en(en)_ADP la(el)_DET cocina(cocina)_NOUN de(de)_ADP Telefónica(Telefónica)_PROPN .(.)_PUNCT
# Frase : Sofía(Sofía)_PROPN juega(jugar)_VERB a(a)_ADP el(el)_DET fútbol(fútbol)_NOUN con(con)_ADP Emma(Emma)_PROPN y(y)_CCONJ Cristina(Cristina)_PROPN con(con)_ADP una(uno)_DET pelota(pelota)_NOUN roja(rojo)_ADJ en(en)_ADP Central(Central)_PROPN Park(Park)_PROPN .(.)_PUNCT
# Frase : El(el)_DET padre(padre)_NOUN de(de)_ADP Marina(Marina)_PROPN tiene(tener)_VERB 56(56)_NUM años(año)_NOUN .(.)_PUNCT
# Frase : La(el)_DET Tierra(Tierra)_PROPN gira(gira)_VERB alrededor(alrededor)_ADV de(de)_ADP el(el)_DET Sol(Sol)_PROPN .(.)_PUNCT
# Frase : Júpiter(Júpiter)_PROPN es(ser)_AUX el(el)_DET planeta(planeta)_NOUN más(más)_ADV grande(grande)_ADJ de(de)_ADP el(el)_DET Sistema(Sistema)_PROPN Solar(Solar)_PROPN

# %% [markdown]
# ## Apartado 1.4
# Ahora incluimos en el Pipeline que se haga un análisis de dependencias (*depparse*)
#
# Obtenemos entonces por cada frase la raiz principial (*root*) y su sujeto (*nsubj*).
#
# (Opcional) Mostrar también sus complementos.

# %%
pipelineStanza = stanza.Pipeline(lang='es', processors='tokenize ,mwt, pos, lemma, depparse')
stanzaDoc = pipelineStanza(text)

print("Número de frases: " + str(len(stanzaDoc.sentences)))
for sentence in stanzaDoc.sentences:
  frase = ""
  for word in sentence.words:
    frase = frase+word.text+"("+word.lemma+")"+"_"+word.upos+" "+"#"+word.deprel+"#"
    if(word.deprel == "root"):
      raiz = word.text
    if(word.deprel =="nsubj"):
      sujeto = word.text
    if(word.deprel =="obj"):
      objeto = word.deprel
  print("Frase : "+frase)
  print("Sujeto :",sujeto," Raiz : ",raiz," Objeto : ",objeto)
# Out:
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# INFO:stanza:Loading these models for language: es (Spanish):
# ===============================
# | Processor | Package         |
# -------------------------------
# | tokenize  | ancora          |
# | mwt       | ancora          |
# | pos       | ancora_charlm   |
# | lemma     | ancora_nocharlm |
# | depparse  | ancora_charlm   |
# ===============================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: mwt
# INFO:stanza:Loading: pos
# INFO:stanza:Loading: lemma
# INFO:stanza:Loading: depparse
# INFO:stanza:Done loading processors!
# Número de frases: 5
# Frase : Hugo(Hugo)_PROPN #nsubj#come(come)_VERB #root#manzanas(manzana)_NOUN #obj#en(en)_ADP #case#la(el)_DET #det#cocina(cocina)_NOUN #obl#de(de)_ADP #case#Telefónica(Telefónica)_PROPN #nmod#.(.)_PUNCT #punct#
# Sujeto : Hugo  Raiz :  come  Objeto :  obj
# Frase : Sofía(Sofía)_PROPN #nsubj#juega(jugar)_VERB #root#a(a)_ADP #case#el(el)_DET #det#fútbol(fútbol)_NOUN #obj#con(con)_ADP #case#Emma(Emma)_PROPN #obl#y(y)_CCONJ #cc#Cristina(Cristina)_PROPN #conj#con(con)_ADP #case#una(uno)_DET #det#pelota(pelota)_NOUN #obl#roja(rojo)_ADJ #amod#en(en)_ADP #case#Central(Central)_PROPN #nmod#Park(Park)_PROPN #flat#.(.)_PUNCT #punct#
# Sujeto : Sofía  Raiz :  juega  Objeto :  obj
# Frase : El(el)_DET #det#padre(padre)_NOUN #nsubj#de(de)_ADP #case#Marina(Marina)_PROPN #nmod#tiene(tener)_VERB #root#56(56)_NUM #nummod#años(año)_NOUN #obj#.(.)_PUNCT #punct#
# Sujeto : padre  Raiz :  tiene  Objeto :  obj
# Frase : La(el)_DET #det#Tierra(Tierra)_PROPN #nsubj#gira(gira)_VERB #root#alrededor(alrededor)_ADV #advmod#de(de)_ADP #case#el(el)_DET #det#Sol(Sol)_PROPN #obl#.(.)_PUNCT #punct#
# Sujeto : Tierra  Raiz :  gira  Objeto :  obj
# Frase : Júpiter(Júpiter)_PROPN #nsubj#es(ser)_AUX #cop#el(el)_DET #det#planeta(planeta)_NOUN #root#más(más)_ADV #advmod#grande(grande)_ADJ #amod#de(de)_ADP #case#el(el)_DET #det#Sistema(Sistema)_PROPN #nmod#Solar(Solar)_PROPN #flat#
# Sujeto : Júpiter  Raiz :  planeta  Objeto :  obj

# %% [markdown]
# ## Apartado 1.5
#
# Por último, incluimos una detección de entidades (*ner*) en el Pipeline y mostramos únicamente las entidades de cada frase que se encuentran en la colección *ents* de *sentence*

# %%
pipelineStanza = stanza.Pipeline(lang='es', processors='tokenize ,mwt, pos, lemma, depparse,ner')
stanzaDoc = pipelineStanza(text)

print("Número de frases: " + str(len(stanzaDoc.sentences)))
for sentence in stanzaDoc.sentences:
  frase = ""
  for ent in sentence.ents:
    print(ent)
# Out:
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# INFO:stanza:Loading these models for language: es (Spanish):
# ===============================
# | Processor | Package         |
# -------------------------------
# | tokenize  | ancora          |
# | mwt       | ancora          |
# | pos       | ancora_charlm   |
# | lemma     | ancora_nocharlm |
# | depparse  | ancora_charlm   |
# | ner       | conll02         |
# ===============================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: mwt
# INFO:stanza:Loading: pos
# INFO:stanza:Loading: lemma
# INFO:stanza:Loading: depparse
# INFO:stanza:Loading: ner
# INFO:stanza:Done loading processors!
# Número de frases: 5
# {
#   "text": "Hugo",
#   "type": "PER",
#   "start_char": 0,
#   "end_char": 4
# }
# {
#   "text": "Valencia",
#   "type": "ORG",
#   "start_char": 6,
#   "end_char": 14
# }
# {
#   "text": "Juan Manuel Garcia Martinez",
#   "type": "PER",
#   "start_char": 29,
#   "end_char": 56
# }
# {
#   "text": "Emma",
#   "type": "PER",
#   "start_char": 77,
#   "end_char": 81
# }
# {
#   "text": "Cristina",
#   "type": "PER",
#   "start_char": 84,
#   "end_char": 92
# }
# {
#   "text": "Central Park",
#   "type": "LOC",
#   "start_char": 116,
#   "end_char": 128
# }
# {
#   "text": "Marina",
#   "type": "PER",
#   "start_char": 143,
#   "end_char": 149
# }
# {
#   "text": "Tierra",
#   "type": "MISC",
#   "start_char": 169,
#   "end_char": 175
# }
# {
#   "text": "Sol",
#   "type": "MISC",
#   "start_char": 195,
#   "end_char": 198
# }
# {
#   "text": "Sistema Solar",
#   "type": "MISC",
#   "start_char": 238,
#   "end_char": 251
# }
